# %%
import pandas as pd

file_path = "ph_raw_data.csv"
separator = "|"

df = pd.read_csv(file_path, sep = separator, error_bad_lines = False)
df.head()
# Out:
# C:\Users\seitz\AppData\Local\Temp\ipykernel_5628\3393270977.py:8: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep=separator, error_bad_lines=False)
# b'Skipping line 69603: expected 13 fields, saw 16\n'
# b'Skipping line 180051: expected 13 fields, saw 16\n'
# b'Skipping line 288908: expected 13 fields, saw 16\n'
# b'Skipping line 353159: expected 13 fields, saw 16\n'
# b'Skipping line 397049: expected 13 fields, saw 16\nSkipping line 398969: expected 13 fields, saw 16\nSkipping line 426934: expected 13 fields, saw 16\nSkipping line 450018: expected 13 fields, saw 16\nSkipping line 454034: expected 13 fields, saw 16\n'
# b'Skipping line 498951: expected 13 fields, saw 16\nSkipping line 508879: expected 13 fields, saw 16\nSkipping line 514484: expected 13 fields, saw 16\nSkipping line 524225: expected 13 fields, saw 16\n'
# ...

# %%
import pandas as pd

df_test = pd.read_csv("ph_raw_data.csv", on_bad_lines = "skip")
df_test.head()
# Out:
#   <iframe src="https://www.pornhub.com/embed/f4cc0ad3819a36752467" frameborder="0" height="481" width="608" scrolling="no"></iframe>|https://di.phncdn.com/videos/200708/12/347/original/(m=eaf8GgaaaWavb)(mh=tDd4ubbYfE8zo0qI)7.jpg|https://di.phncdn.com/videos/200708/12/347/original/(m=eaf8GgaaaWavb)(mh=tDd4ubbYfE8zo0qI)1.jpg;https://di.phncdn.com/videos/200708/12/347/original/(m=eaf8GgaaaWavb)(mh=tDd4ubbYfE8zo0qI)2.jpg;https://di.phncdn.com/videos/200708/12/347/original/(m=eaf8GgaaaWavb)(mh=tDd4ubbYfE8zo0qI)3.jpg;https://di.phncdn.com/videos/200708/12/347/original/(m=eaf8GgaaaWavb)(mh=tDd4ubbYfE8zo0qI)4.jpg;https://di.phncdn.com/videos/200708/12/347/original/(m=eaf8GgaaaWavb)(mh=tDd4ubbYfE8zo0qI)5.jpg;https://di.phncdn.com/videos/200708/12/347/original/(m=eaf8GgaaaWavb)(mh=tDd4ubbYfE8zo0qI)6.jpg;https://di.phncdn.com/videos/200708/12/347/original/(m=eaf8GgaaaWavb)(mh=tDd4ubbYfE8zo0qI)7.jpg;https://di.phncdn.com/videos/200708/12/347/original/(m=eaf8GgaaaWavb)(mh=tDd4ubbYfE8zo0qI)8.jpg;h
# ...

# %%
import pandas as pd

df = pd.read_csv("ph_cleaned_data_oct_31.csv")
df.head()
# Out:
#                                                embed  \
# 0  <iframe src="https://www.pornhub.com/embed/f4c...
# 1  <iframe src="https://www.pornhub.com/embed/3ee...
# 2  <iframe src="https://www.pornhub.com/embed/e5e...
# 3  <iframe src="https://www.pornhub.com/embed/f8e...
# 4  <iframe src="https://www.pornhub.com/embed/e32...
#
#                                           thubnail_1  \
# 0  https://di.phncdn.com/videos/200708/12/347/ori...
# 1  https://di.phncdn.com/videos/200705/06/417/ori...
# 2  https://di.phncdn.com/videos/200704/18/518/ori...
# 3  https://di.phncdn.com/videos/200706/05/592/ori...
# 4  https://di.phncdn.com/videos/201010/27/6991/or...
#
#                                          thumbnail_2  \
# 0  https://di.phncdn.com/videos/200708/12/347/ori...
# 1  https://di.phncdn.com/videos/200705/06/417/ori...
# 2  https://di.phncdn.com/videos/200704/18/518/ori...
# 3  https://di.phncdn.com/videos/200706/05/592/ori...
# ...

# %%
len(df)
# Out:
# 588867

# %%
df.describe()
# Out:
#             duration         views          likes       dislikes
# count  588867.000000  5.888670e+05  567443.000000  567443.000000
# mean      895.671335  3.022972e+05     809.663157     196.020777
# std       734.384730  1.659274e+06    4529.138612    1560.739501
# min         1.000000  0.000000e+00       0.000000       0.000000
# 25%       444.000000  3.091000e+03      25.000000       2.000000
# 50%       701.000000  2.566900e+04     115.000000      15.000000
# 75%      1219.000000  1.526275e+05     434.000000      75.000000
# max     43199.000000  2.634831e+08  712507.000000  275601.000000
